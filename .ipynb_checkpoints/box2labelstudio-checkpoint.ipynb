# %%
import cv2
import pytesseract
import json
img = cv2.imread('/Volumes/Non-Backup_Files/tesseract_pre1900_training/JPGS/1617-1650/GB161800009/eng.times.GB1618000091.jpg')

h, w, c = img.shape
boxes = pytesseract.image_to_boxes(img)

# %%
def convert_to_ls(x, y, width, height, original_width, original_height):
    return x / original_width * 100.0, y / original_height * 100.0, \
           width / original_width * 100.0, height / original_height * 100

# %%
img.shape
# Out:
# (2131, 1442, 3)

# %%
og_height = img.shape[0]
og_width = img.shape[1]

# %%
print(boxes)
# Out:
# A 554 1978 584 2011 0
# . 590 1978 597 1984 0
# D 599 1977 635 2011 0
# . 639 1978 645 1983 0
# 1 668 1978 680 2011 0
# 6 689 1977 710 2011 0
# 1 718 1978 728 2011 0
# 8 737 1958 760 2014 0
# : 761 1978 769 2006 0
# — 772 1986 821 1991 0
# N 823 1977 856 2011 0
# ° 844 1956 869 2008 0
# 9 887 1976 908 2009 0
# G 341 1908 364 1932 0
# i 352 1908 372 1923 0
# l 371 1909 383 1932 0
# b 384 1908 395 1932 0
# e 397 1908 414 1923 0
# r 415 1919 420 1923 0
# t 421 1909 435 1932 0
# s 436 1909 445 1923 0
# E 458 1909 482 1933 0
# n 479 1910 489 1933 0
# g 492 1901 513 1924 0
# i 516 1910 523 1933 0
# n 524 1910 537 1932 0
# e 540 1910 551 1925 0
# s 550 1910 560 1925 0
# f 569 1902 592 1933 0
# o 589 1910 601 1925 0
# r 602 1908 624 1935 0
# D 627 1910 658 1933 0
# r 659 1910 672 1924 0
# e 672 1910 683 1925 0
# d 683 1910 700 1933 0
# g 697 1903 713 1925 0
# i 714 1910 723 1933 0
# n 724 1911 738 1925 0
# g 738 1903 755 1926 0
# R 766 1910 793 1934 0
# i 794 1911 803 1925 0
# ...

# %%
boxes_list = boxes.split('\n')
boxes_list = [el.split() for el in boxes_list]
boxes_list
# Out:
# [['A', '554', '1978', '584', '2011', '0'],
#  ['.', '590', '1978', '597', '1984', '0'],
#  ['D', '599', '1977', '635', '2011', '0'],
#  ['.', '639', '1978', '645', '1983', '0'],
#  ['1', '668', '1978', '680', '2011', '0'],
#  ['6', '689', '1977', '710', '2011', '0'],
#  ['1', '718', '1978', '728', '2011', '0'],
#  ['8', '737', '1958', '760', '2014', '0'],
#  [':', '761', '1978', '769', '2006', '0'],
#  ['—', '772', '1986', '821', '1991', '0'],
#  ['N', '823', '1977', '856', '2011', '0'],
#  ['°', '844', '1956', '869', '2008', '0'],
#  ['9', '887', '1976', '908', '2009', '0'],
#  ['G', '341', '1908', '364', '1932', '0'],
#  ['i', '352', '1908', '372', '1923', '0'],
#  ['l', '371', '1909', '383', '1932', '0'],
#  ['b', '384', '1908', '395', '1932', '0'],
#  ['e', '397', '1908', '414', '1923', '0'],
#  ['r', '415', '1919', '420', '1923', '0'],
#  ['t', '421', '1909', '435', '1932', '0'],
#  ['s', '436', '1909', '445', '1923', '0'],
#  ['E', '458', '1909', '482', '1933', '0'],
# ...

# %%
# output = [
#     {"id":1,
#      "annotations":[
#          {"id":2,"completed_by":1,"result":[
#              {"original_width":1442,"original_height":2131,"image_rotation":0,"value":{"x":17.357910906298002,"y":12.266112266112266,"width":2.61136712749616,"height":1.4553014553014554,"rotation":0},"id":"IC9xqh_FqR","from_name":"bbox","to_name":"image","type":"rectangle","origin":"manual"}
#             ,{"original_width":1442,"original_height":2131,"image_rotation":0,"value":{"x":17.357910906298002,"y":12.266112266112266,"width":2.61136712749616,"height":1.4553014553014554,"rotation":0,"text":["k"]},"id":"IC9xqh_FqR","from_name":"transcription","to_name":"image","type":"textarea","origin":"manual"}]
#           ,"was_cancelled":false,
#           "ground_truth":false,
#           "created_at":"2022-01-26T15:08:55.467002Z",
#           "updated_at":"2022-01-26T15:09:00.132418Z",
#           "lead_time":190.981,
#           "prediction":{},
#           "result_count":0,
#           "task":1,
#           "parent_prediction":null,
#           "parent_annotation":null}],
#      "file_upload":"f66de0d3-eng.times.GB1618000091.jpg",
#      "drafts":[],
#      "predictions":[],
#      "data":{
#          "ocr":"\/data\/upload\/11\/f66de0d3-eng.times.GB1618000091.jpg"},
#          "meta":{},
#          "created_at":"2022-01-26T09:12:08.640299Z",
#          "updated_at":"2022-01-26T15:09:00.105244Z",
#          "project":11}]

# %%
output = [{"id":1,"annotations":[{"id":10,"completed_by":1,"result":[],"was_cancelled":False,"ground_truth":False,"created_at":"2022-01-26T16:27:50.886546Z","updated_at":"2022-01-26T16:27:52.998560Z","lead_time":102.167,"prediction":{},"result_count":0,"task":1,"parent_prediction":None,"parent_annotation":None}],"file_upload":"767056b3-eng.times.GB1618000091.jpg","drafts":[],"predictions":[],"data":{"ocr":"\/data\/upload\/11\/767056b3-eng.times.GB1618000091.jpg"},"meta":{},"created_at":"2022-01-26T16:27:19.282681Z","updated_at":"2022-01-26T16:27:52.968421Z","project":11}]

# %%
# output = [{"id":0, "predictions":[{"id": 0, "result":[], "task":"ocr",}], "data": {"ocr": "/data/upload/eng.times.GB1618000091.jpg"}, "project":1 }]
# output = [{"id":0, "predictions":[{"id": 0, "result":[]}], "data": {"ocr": "/data/upload/eng.times.GB1618000091.jpg"}}]
# output = [{"id":2, "predictions":[
#     {"id": 3, "result":[], "task":1}], "file_upload":"f66de0d3-eng.times.GB1618000091.jpg", "data": {"ocr":"\/data\/upload\/11\/f66de0d3-eng.times.GB1618000091.jpg"},
#          "meta":{}, "project":11}]

            
for box_i in range(len(boxes_list)):
    try:
        label, xmin, ymin, xmax, ymax, rot = boxes_list[box_i]
        xmin = float(xmin)
        ymin = float(ymin)
        xmax = float(xmax)
        ymax = float(ymax)
        rot = float(rot)
        x_perc, y_perc, width_perc, height_perc = convert_to_ls(xmin, ymin, xmax-xmin+1, ymax-ymin+1, og_width, og_height)
          
        transcript_dict = {"original_width":og_width,
                    "original_height":og_height,
                    "image_rotation":0,
                    "value":{                   
                       "x":x_perc,
                         "y":y_perc,
                         "width":width_perc,
                         "height":height_perc,
                         "rotation":rot,
                        "text": [
                        label
                          ]},                 
                    "id":str(box_i),
                    "from_name": "transcription",
                    "to_name": "image",
                    "type": "textarea",
                    "origin":"manual"}
        bbox_dict = {
            "original_width":og_width,
            "original_height":og_height,
            "image_rotation":0,
            "id":str(box_i),
            "from_name": "bbox",
            "to_name": "image",
            "type": "rectangle",
            "value": {
                 "x":x_perc,
                 "y":y_perc,
                 "width":width_perc,
                 "height":height_perc,
                 "rotation":rot
            }
            ,"origin":"manual"
          }
        
        output[0]["annotations"][0]["result"].append(bbox_dict)
        output[0]["annotations"][0]["result"].append(transcript_dict)
    except:
        print('empty annotation')
# Out:
# empty annotation

# %%
output
# Out:
# [{'id': 1,
#   'annotations': [{'id': 10,
#     'completed_by': 1,
#     'result': [{'original_width': 1442,
#       'original_height': 2131,
#       'image_rotation': 0,
#       'id': '0',
#       'from_name': 'bbox',
#       'to_name': 'image',
#       'type': 'rectangle',
#       'value': {'x': 38.41886269070735,
#        'y': 92.82027217268887,
#        'width': 2.1497919556171983,
#        'height': 1.5954950727358048,
#        'rotation': 0.0},
#       'origin': 'manual'},
#      {'original_width': 1442,
#       'original_height': 2131,
#       'image_rotation': 0,
#       'value': {'x': 38.41886269070735,
#        'y': 92.82027217268887,
#        'width': 2.1497919556171983,
#        'height': 1.5954950727358048,
#        'rotation': 0.0,
#        'text': ['A']},
#       'id': '0',
#       'from_name': 'transcription',
#       'to_name': 'image',
#       'type': 'textarea',
#       'origin': 'manual'},
#      {'original_width': 1442,
#       'original_height': 2131,
# ...

# %%
with open('/Users/andrealphonse/Documents/UniStuff/MA/MA5/lhst_project/tesseract_pre1900_training/JPGS/1617-1650/GB161800009/eng.times.GB1618000091.json', 'w') as f:
    json.dump(output, f)

# %% [markdown]
# # Examples of label studio input

# %%
[
    {"id":1,
     "annotations":[
         {"id":2,"completed_by":1,"result":[{"original_width":1442,"original_height":2131,"image_rotation":0,"value":{"x":17.357910906298002,"y":12.266112266112266,"width":2.61136712749616,"height":1.4553014553014554,"rotation":0},"id":"IC9xqh_FqR","from_name":"bbox","to_name":"image","type":"rectangle","origin":"manual"}
                                            ,{"original_width":1442,"original_height":2131,"image_rotation":0,"value":{"x":17.357910906298002,"y":12.266112266112266,"width":2.61136712749616,"height":1.4553014553014554,"rotation":0,"text":["k"]},"id":"IC9xqh_FqR","from_name":"transcription","to_name":"image","type":"textarea","origin":"manual"}]
          ,"was_cancelled":false,
          "ground_truth":false,
          "created_at":"2022-01-26T15:08:55.467002Z",
          "updated_at":"2022-01-26T15:09:00.132418Z",
          "lead_time":190.981,
          "prediction":{},
          "result_count":0,
          "task":1,
          "parent_prediction":null,
          "parent_annotation":null}],
     "file_upload":"f66de0d3-eng.times.GB1618000091.jpg",
     "drafts":[],
     "predictions":[],
     "data":{"ocr":"\/data\/upload\/11\/f66de0d3-eng.times.GB1618000091.jpg"},
     "meta":{},
     "created_at":"2022-01-26T09:12:08.640299Z",
     "updated_at":"2022-01-26T15:09:00.105244Z",
     "project":11}]

# %%
  {
    "data": {
      "ocr": "/data/upload/receipt_00491.png"
    },
    "predictions": [
      {
        "result": [
          {
            "id": "49ab7bc9-8",
            "from_name": "bbox",
            "to_name": "image",
            "type": "rectangle",
            "value": {
              "x": 17.824074074074073,
              "y": 38.73456790123457,
              "width": 40.50925925925926,
              "height": 1.1574074074074074,
              "rotation": 0
            }
          },
          {
            "id": "49ab7bc9-8",
            "from_name": "transcription",
            "to_name": "image",
            "type": "textarea",
            "value": {
              "text": [
                "\u2014 \u2014_"
              ],
              "x": 17.824074074074073,
              "y": 38.73456790123457,
              "width": 40.50925925925926,
              "height": 1.1574074074074074,
              "rotation": 0
            },
            "score": 0.16999999999999998
          },
          {
            "id": "0d34f875-b",
            "from_name": "bbox",
            "to_name": "image",
            "type": "rectangle",
            "value": {
              "x": 21.64351851851852,
              "y": 46.75925925925926,
              "width": 65.16203703703704,
              "height": 2.623456790123457,
              "rotation": 0
            }
          },
          {
            "id": "0d34f875-b",
            "from_name": "transcription",
            "to_name": "image",
            "type": "textarea",
            "value": {
              "text": [
                "1 CUSTARD SOBI RO 12,000"
              ],
              "x": 21.64351851851852,
              "y": 46.75925925925926,
              "width": 65.16203703703704,
              "height": 2.623456790123457,
              "rotation": 0
            },
            "score": 0.8459999999999999
          },
          {
            "id": "5c1d085b-4",
            "from_name": "bbox",
            "to_name": "image",
            "type": "rectangle",
            "value": {
              "x": 24.88425925925926,
              "y": 50.69444444444444,
              "width": 61.574074074074076,
              "height": 9.25925925925926,
              "rotation": 0
            }
          },
          {
            "id": "5c1d085b-4",
            "from_name": "transcription",
            "to_name": "image",
            "type": "textarea",
            "value": {
              "text": [
                "TOTAL = 21,000"
              ],
              "x": 24.88425925925926,
              "y": 50.69444444444444,
              "width": 61.574074074074076,
              "height": 9.25925925925926,
              "rotation": 0
            },
            "score": 0.43333333333333335
          },
          {
            "id": "8d9a123f-f",
            "from_name": "bbox",
            "to_name": "image",
            "type": "rectangle",
            "value": {
              "x": 24.074074074074073,
              "y": 57.098765432098766,
              "width": 62.15277777777778,
              "height": 8.641975308641975,
              "rotation": 0
            }
          },
          {
            "id": "8d9a123f-f",
            "from_name": "transcription",
            "to_name": "image",
            "type": "textarea",
            "value": {
              "text": [
                "CHANGE 0"
              ],
              "x": 24.074074074074073,
              "y": 57.098765432098766,
              "width": 62.15277777777778,
              "height": 8.641975308641975,
              "rotation": 0
            },
            "score": 0.715
          }
        ],
        "score": 0.5410833333333332
      }
    ]
  },
